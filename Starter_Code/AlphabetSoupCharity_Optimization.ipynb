# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# ...

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.

app_df = application_df.drop(['EIN', 'NAME'], axis=1)

# %%
# Determine the number of unique values in each column.
counts = app_df.nunique()
print(counts)
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
app_type_val = app_df['APPLICATION_TYPE'].value_counts()
app_type_val
# Out:
# APPLICATION_TYPE
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: count, dtype: int64

# %%
# Separate values to be replaced
application_types_to_replace = ["T9", "T13", "T12", "T2", "T25", "T14", "T29", "T15", "T17"]

# %%
# Replace in dataframe
for app in application_types_to_replace:
    app_df['APPLICATION_TYPE'] = app_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
app_df['APPLICATION_TYPE'].value_counts()
# Out:
# APPLICATION_TYPE
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: count, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
class_val_counts = app_df['CLASSIFICATION'].value_counts()
class_val_counts
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: count, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
filtered_counts = class_val_counts[class_val_counts > 1]
filtered_counts
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: count, dtype: int64

# %%
classifications_to_replace = class_val_counts[class_val_counts < 1883]

# Replace in dataframe
for cls in classifications_to_replace.index:  # Iterate over index labels
    app_df['CLASSIFICATION'] = app_df['CLASSIFICATION'].replace(cls, "Other")

# Check to make sure binning was successful
print(app_df['CLASSIFICATION'].value_counts())
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: count, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
app_df = pd.get_dummies(app_df)
app_df.head()
# Out:
#    STATUS  ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_Other  \
# 0       1     5000              1                   False
# 1       1   108590              1                   False
# 2       1     5000              0                   False
# 3       1     6692              1                   False
# 4       1   142590              1                   False
#
#    APPLICATION_TYPE_T10  APPLICATION_TYPE_T19  APPLICATION_TYPE_T3  \
# 0                  True                 False                False
# 1                 False                 False                 True
# 2                 False                 False                False
# 3                 False                 False                 True
# 4                 False                 False                 True
#
#    APPLICATION_TYPE_T4  APPLICATION_TYPE_T5  APPLICATION_TYPE_T6  ...  \
# 0                False                False                False  ...
# ...

# %%
# Split our preprocessed data into our features and target arrays
y = app_df['IS_SUCCESSFUL']
X = app_df.drop(columns='IS_SUCCESSFUL')

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, stratify=y)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
#  Added a second hidden layer with 15 neurons. Decreased epochs to 50

nn = tf.keras.models.Sequential()
nn.add(tf.keras.layers.Dense(units=80, activation="relu", input_dim=43))


# First hidden layer
nn.add(tf.keras.layers.Dense(units=30, activation="relu"))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=15, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 80)                3520
#
#  dense_1 (Dense)             (None, 30)                2430
#
#  dense_2 (Dense)             (None, 15)                465
#
#  dense_3 (Dense)             (None, 1)                 16
#
# ...
# Total params: 6431 (25.12 KB)
# Trainable params: 6431 (25.12 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# call back to save models weights every 5 epochs
class SaveWeightsCallback(tf.keras.callbacks.Callback):
    def __init__(self, save_path):
        super(SaveWeightsCallback, self).__init__()
        self.save_path = save_path
        self.epoch_count = 0

    def on_epoch_end(self, epoch, logs=None):
        if (epoch + 1) % 5 == 0:  # Save weights every 5 epochs
            self.model.save_weights(f"{self.save_path}_epoch_{epoch+1}.h5")
            print(f"Saved weights at epoch {epoch+1}")


save_callback = SaveWeightsCallback(save_path="model_weights")

# %%
# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs=50, callbacks=[save_callback])
# Out:
# Epoch 1/50
# 804/804 [==============================] - 3s 2ms/step - loss: 0.5693 - accuracy: 0.7219
# Epoch 2/50
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5546 - accuracy: 0.7303
# Epoch 3/50
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5508 - accuracy: 0.7327
# Epoch 4/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5488 - accuracy: 0.7349
# Epoch 5/50
# ...
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5484 - accuracy: 0.7334
# Epoch 6/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5474 - accuracy: 0.7347
# Epoch 7/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5469 - accuracy: 0.7350
# Epoch 8/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5457 - accuracy: 0.7352
# Epoch 9/50
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5456 - accuracy: 0.7362
# Epoch 10/50
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5584 - accuracy: 0.7252 - 451ms/epoch - 2ms/step
# Loss: 0.5584294199943542, Accuracy: 0.7252478003501892

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
# Removed the second hidden layer, increased first hidden layer neurons to 40.
# Increased epochs to 100.

nn = tf.keras.models.Sequential()
nn.add(tf.keras.layers.Dense(units=80, activation="relu", input_dim=43))


# First hidden layer
nn.add(tf.keras.layers.Dense(units=40, activation="relu"))

# Second hidden layer


# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_4 (Dense)             (None, 80)                3520
#
#  dense_5 (Dense)             (None, 40)                3240
#
#  dense_6 (Dense)             (None, 1)                 41
#
# ...
# Total params: 6801 (26.57 KB)
# Trainable params: 6801 (26.57 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# call back to save models weights every 5 epochs
class SaveWeightsCallback(tf.keras.callbacks.Callback):
    def __init__(self, save_path):
        super(SaveWeightsCallback, self).__init__()
        self.save_path = save_path
        self.epoch_count = 0

    def on_epoch_end(self, epoch, logs=None):
        if (epoch + 1) % 5 == 0:  # Save weights every 5 epochs
            self.model.save_weights(f"{self.save_path}_epoch_{epoch+1}.h5")
            print(f"Saved weights at epoch {epoch+1}")


save_callback = SaveWeightsCallback(save_path="model_weights")

# %%
# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs=100, callbacks=[save_callback])
# Out:
# Epoch 1/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5698 - accuracy: 0.7225
# Epoch 2/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5554 - accuracy: 0.7311
# Epoch 3/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5520 - accuracy: 0.7327
# Epoch 4/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5503 - accuracy: 0.7328
# Epoch 5/100
# ...
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5486 - accuracy: 0.7328
# Epoch 6/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5483 - accuracy: 0.7336
# Epoch 7/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5473 - accuracy: 0.7345
# Epoch 8/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5460 - accuracy: 0.7360
# Epoch 9/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5458 - accuracy: 0.7346
# Epoch 10/100
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5642 - accuracy: 0.7236 - 422ms/epoch - 2ms/step
# Loss: 0.5642383098602295, Accuracy: 0.7236151695251465

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
# Increased first hidden layer neurons to 60.
# Added second layer with tanh activation and 60 neurons.

nn = tf.keras.models.Sequential()
nn.add(tf.keras.layers.Dense(units=80, activation="relu", input_dim=43))


# First hidden layer
nn.add(tf.keras.layers.Dense(units=60, activation="relu"))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=60, activation="tanh"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_10 (Dense)            (None, 80)                3520
#
#  dense_11 (Dense)            (None, 60)                4860
#
#  dense_12 (Dense)            (None, 60)                3660
#
#  dense_13 (Dense)            (None, 1)                 61
#
# ...
# Total params: 12101 (47.27 KB)
# Trainable params: 12101 (47.27 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# call back to save models weights every 5 epochs
class SaveWeightsCallback(tf.keras.callbacks.Callback):
    def __init__(self, save_path):
        super(SaveWeightsCallback, self).__init__()
        self.save_path = save_path
        self.epoch_count = 0

    def on_epoch_end(self, epoch, logs=None):
        if (epoch + 1) % 5 == 0:  # Save weights every 5 epochs
            self.model.save_weights(f"{self.save_path}_epoch_{epoch+1}.h5")
            print(f"Saved weights at epoch {epoch+1}")


save_callback = SaveWeightsCallback(save_path="model_weights")

# %%
# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs=100, callbacks=[save_callback])
# Out:
# Epoch 1/100
# 804/804 [==============================] - 3s 2ms/step - loss: 0.5673 - accuracy: 0.7227
# Epoch 2/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5552 - accuracy: 0.7310
# Epoch 3/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5526 - accuracy: 0.7318
# Epoch 4/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5504 - accuracy: 0.7334
# Epoch 5/100
# ...
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5494 - accuracy: 0.7339
# Epoch 6/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5485 - accuracy: 0.7338
# Epoch 7/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5473 - accuracy: 0.7346
# Epoch 8/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5464 - accuracy: 0.7350
# Epoch 9/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5457 - accuracy: 0.7352
# Epoch 10/100
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5610 - accuracy: 0.7248 - 426ms/epoch - 2ms/step
# Loss: 0.5610349178314209, Accuracy: 0.724781334400177

# %%
# Export our model to HDF5 file
nn.save("AlphabetSoupCharity_Optimization.h5")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
